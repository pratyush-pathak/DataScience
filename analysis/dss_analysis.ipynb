# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pd.set_option('display.max_column', None)

# %%
dssalary = pd.read_csv('dssalary.csv')

# %%
dssalary
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
dssalary.head()
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2023               EN              FT        Applied Scientist
# 1       2023               EN              FT        Applied Scientist
# 2       2023               EN              FT     Data Quality Analyst
# 3       2023               EN              FT  Compliance Data Analyst
# 4       2023               EN              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
dssalary.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               EN              FT          Applied Scientist
# 1       2023               EN              FT          Applied Scientist
# 2       2023               EN              FT       Data Quality Analyst
# 3       2023               EN              FT    Compliance Data Analyst
# 4       2023               EN              FT          Applied Scientist
# 5       2023               EN              FT          Applied Scientist
# 6       2023               EN              FT  Machine Learning Engineer
# 7       2023               EN              FT  Machine Learning Engineer
# 8       2023               EN              FT         Research Scientist
# 9       2023               EN              FT              Data Engineer
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# ...

# %%
dssalary.tail()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %%
dssalary.tail(10)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3751       2020               SE              FT         Lead Data Engineer
# 3752       2020               SE              FT          Big Data Engineer
# 3753       2020               SE              FT              Data Engineer
# 3754       2020               SE              FT             Data Scientist
# 3755       2020               SE              FL   Computer Vision Engineer
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# ...

# %%
dssalary.sample()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3380       2022               SE              FT  Machine Learning Engineer
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3380  192600             USD         192600               US            M

# %%
dssalary.sample(5)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 436        2023               MI              FT              Data Analyst
# 2148       2022               MI              FT  Data Operations Engineer
# 671        2023               SE              FT             Data Engineer
# 1649       2023               SE              FT               ML Engineer
# 3419       2022               SE              FT             Data Engineer
#
#       salary salary_currency  salary_in_usd company_location company_size
# 436   160000             USD         160000               US            M
# 2148  100000             USD         100000               US            M
# 671   140000             USD         140000               US            M
# 1649  234100             USD         234100               US            M
# 3419  220110             USD         220110               US            M

# %% [markdown]
# - Selecting Column

# %%
dssalary['salary']
# Out:
# 0       213660
# 1       130760
# 2       100000
# 3        30000
# 4       204620
#          ...
# 3756    130000
# 3757     80000
# 3758    190200
# 3759     40000
# 3760    412000
# Name: salary, Length: 3761, dtype: int64

# %%
dssalary.salary
# Out:
# 0       213660
# 1       130760
# 2       100000
# 3        30000
# 4       204620
#          ...
# 3756    130000
# 3757     80000
# 3758    190200
# 3759     40000
# 3760    412000
# Name: salary, Length: 3761, dtype: int64

# %%
mul = ['work_year', 'job_title', 'salary']
dssalary[mul]
# Out:
#       work_year                  job_title  salary
# 0          2023          Applied Scientist  213660
# 1          2023          Applied Scientist  130760
# 2          2023       Data Quality Analyst  100000
# 3          2023    Compliance Data Analyst   30000
# 4          2023          Applied Scientist  204620
# ...         ...                        ...     ...
# 3756       2020   Principal Data Scientist  130000
# 3757       2020             Data Scientist   80000
# 3758       2020       Data Science Manager  190200
# 3759       2020  Machine Learning Engineer   40000
# 3760       2020             Data Scientist  412000
#
# [3761 rows x 3 columns]

# %% [markdown]
# - Row wise selecting

# %%
dssalary.iloc[4]
# Out:
# work_year                        2023
# experience_level                   EN
# employment_type                    FT
# job_title           Applied Scientist
# salary                         204620
# salary_currency                   USD
# salary_in_usd                  204620
# company_location                   US
# company_size                        L
# Name: 4, dtype: object

# %%
dssalary.iloc[:5]
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2023               EN              FT        Applied Scientist
# 1       2023               EN              FT        Applied Scientist
# 2       2023               EN              FT     Data Quality Analyst
# 3       2023               EN              FT  Compliance Data Analyst
# 4       2023               EN              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
dssalary.iloc[4,4:]
# Out:
# salary              204620
# salary_currency        USD
# salary_in_usd       204620
# company_location        US
# company_size             L
# Name: 4, dtype: object

# %%
dssalary.iloc[4,[4,6]].plot(kind='bar')
# Out:
# <Axes: >

# %%
dssalary.index
# Out:
# RangeIndex(start=0, stop=3761, step=1)

# %%
dssalary.describe(exclude=np.number)
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count              3761            3761           3761            3761
# unique                4               4             93              20
# top                  SE              FT  Data Engineer             USD
# freq               2518            3724           1040            3229
#
#        company_location company_size
# count              3761         3761
# unique               72            3
# top                  US            M
# freq               3045         3157

# %% [markdown]
# - Sort

# %%
dssalary.sort_values(by='salary', ascending=True)
# Out:
#       work_year experience_level employment_type  \
# 1797       2022               EN              FT
# 40         2023               EN              FT
# 2179       2022               MI              CT
# 3732       2020               MI              FT
# 2855       2022               SE              FT
# ...         ...              ...             ...
# 3137       2022               SE              FT
# 3529       2021               MI              FT
# 3727       2020               MI              FT
# 3556       2021               MI              FT
# 3580       2021               MI              FT
#
#                            job_title    salary salary_currency  salary_in_usd  \
# 1797                    AI Developer      6000             EUR           6304
# 40     Autonomous Vehicle Technician      7000             USD           7000
# 2179              Analytics Engineer      7500             USD           7500
# ...

# %%
dssalary.sort_values(by='salary', ascending=False)
# Out:
#       work_year experience_level employment_type  \
# 3580       2021               MI              FT
# 3727       2020               MI              FT
# 3556       2021               MI              FT
# 3529       2021               MI              FT
# 3137       2022               SE              FT
# ...         ...              ...             ...
# 2855       2022               SE              FT
# 3732       2020               MI              FT
# 2179       2022               MI              CT
# 40         2023               EN              FT
# 1797       2022               EN              FT
#
#                            job_title    salary salary_currency  salary_in_usd  \
# 3580                  Data Scientist  30400000             CLP          40038
# 3727                  Data Scientist  11000000             HUF          35735
# 3556                 BI Data Analyst  11000000             HUF          36259
# ...

# %%
dssalary.sort_index()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
dssalary.sort_index(ascending=False)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3760       2020               SE              FT             Data Scientist
# 3759       2020               SE              FT  Machine Learning Engineer
# 3758       2020               SE              FT       Data Science Manager
# 3757       2020               SE              FT             Data Scientist
# 3756       2020               SE              FT   Principal Data Scientist
# ...         ...              ...             ...                        ...
# 4          2023               EN              FT          Applied Scientist
# 3          2023               EN              FT    Compliance Data Analyst
# 2          2023               EN              FT       Data Quality Analyst
# 1          2023               EN              FT          Applied Scientist
# 0          2023               EN              FT          Applied Scientist
#
# ...

# %%
dssalary.sort_values(by='work_year')
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3760       2020               SE              FT             Data Scientist
# 3705       2020               EN              PT             Data Scientist
# 3706       2020               EN              FT             Data Scientist
# 3707       2020               EN              CT      Business Data Analyst
# 3708       2020               EX              FT         Staff Data Analyst
# ...         ...              ...             ...                        ...
# 1198       2023               SE              FT  Machine Learning Engineer
# 1199       2023               SE              FT  Machine Learning Engineer
# 1200       2023               SE              FT               Data Analyst
# 1189       2023               SE              FT  Machine Learning Engineer
# 0          2023               EN              FT          Applied Scientist
#
# ...

# %%
dssalary
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
dssalary.value_counts('company_location')
# Out:
# company_location
# US    3045
# GB     173
# CA      87
# ES      77
# IN      58
#       ...
# EG       1
# MT       1
# MK       1
# MD       1
# VN       1
# Name: count, Length: 72, dtype: int64

# %%
dssalary.value_counts(['work_year','experience_level','job_title'])
# Out:
# work_year  experience_level  job_title
# 2022       SE                Data Engineer               355
# 2023       SE                Data Engineer               349
#                              Data Scientist              299
# 2022       SE                Data Scientist              297
# 2023       SE                Data Analyst                199
#                                                         ...
# 2022       EX                Head of Machine Learning      1
#                              Lead Data Engineer            1
#                              Research Scientist            1
#            MI                Applied Data Scientist        1
# 2023       SE                Software Data Engineer        1
# Name: count, Length: 351, dtype: int64

# %% [markdown]
# - Filtering

# %%
dssalary.value_counts('job_title')
# Out:
# job_title
# Data Engineer                1040
# Data Scientist                840
# Data Analyst                  614
# Machine Learning Engineer     291
# Analytics Engineer            103
#                              ...
# Compliance Data Analyst         1
# Cloud Data Architect            1
# BI Data Engineer                1
# Azure Data Engineer             1
# Staff Data Scientist            1
# Name: count, Length: 93, dtype: int64

# %%
dssalary['job_title'] == 'Data Scientist'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3756    False
# 3757     True
# 3758    False
# 3759    False
# 3760     True
# Name: job_title, Length: 3761, dtype: bool

# %%
dssalary[dssalary['job_title'] == 'Data Scientist'].sort_values(by='salary', ascending=False).reset_index()
# Out:
#      index  work_year experience_level employment_type       job_title  \
# 0     3580       2021               MI              FT  Data Scientist
# 1     3727       2020               MI              FT  Data Scientist
# 2     1839       2022               EN              FT  Data Scientist
# 3     2205       2022               MI              FT  Data Scientist
# 4     3612       2021               SE              FT  Data Scientist
# ..     ...        ...              ...             ...             ...
# 835   2217       2022               MI              FT  Data Scientist
# 836   3573       2021               MI              FT  Data Scientist
# 837   3705       2020               EN              PT  Data Scientist
# 838   3476       2021               EN              FT  Data Scientist
# 839   2147       2022               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd company_location company_size
# ...

# %%
dssalary[dssalary['salary_in_usd']>400000]
# Out:
#       work_year experience_level employment_type  \
# 893        2023               SE              FT
# 2008       2022               MI              FT
# 3449       2022               SE              FT
# 3519       2021               EX              CT
# 3609       2021               MI              FT
# 3714       2020               MI              FT
# 3760       2020               SE              FT
#
#                                job_title   salary salary_currency  \
# 893                         AI Scientist  1500000             ILS
# 2008                        Data Analyst   350000             GBP
# 3449                 Data Analytics Lead   405000             USD
# 3519            Principal Data Scientist   416000             USD
# 3609  Applied Machine Learning Scientist   423000             USD
# 3714                  Research Scientist   450000             USD
# 3760                      Data Scientist   412000             USD
#
# ...

# %% [markdown]
# - describe function

# %%
dssalary.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
dssalary.describe(exclude=np.number)
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count              3761            3761           3761            3761
# unique                4               4             93              20
# top                  SE              FT  Data Engineer             USD
# freq               2518            3724           1040            3229
#
#        company_location company_size
# count              3761         3761
# unique               72            3
# top                  US            M
# freq               3045         3157

# %%
dssalary
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
cols_to_drop = ['salary','salary_currency', 'company_size']

dssalary.drop(columns=cols_to_drop, inplace=True)

# %%
dssalary
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary_in_usd company_location
# ...

# %%
dssalary.value_counts('work_year')
# Out:
# work_year
# 2023    1789
# 2022    1666
# 2021     230
# 2020      76
# Name: count, dtype: int64

# %%
dssalary.value_counts('experience_level')
# Out:
# experience_level
# SE    2518
# MI     809
# EN     320
# EX     114
# Name: count, dtype: int64

# %%
dssalary.drop_duplicates(subset=['job_title'])
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 6          2023               EN              FT  Machine Learning Engineer
# 8          2023               EN              FT         Research Scientist
# ...         ...              ...             ...                        ...
# 3615       2021               SE              FT       Cloud Data Architect
# 3623       2021               SE              FT    Principal Data Engineer
# 3656       2021               SE              CT       Staff Data Scientist
# 3676       2021               SE              FT       Finance Data Analyst
# 3708       2020               EX              FT         Staff Data Analyst
#
#       salary_in_usd company_location
# ...

# %%
# reordering
updated_list = ['job_title','work_year','employment_type','company_location','experience_level','salary_in_usd']
print(updated_list)
# Out:
# ['job_title', 'work_year', 'employment_type', 'company_location', 'experience_level', 'salary_in_usd']

# %%
dssalary = dssalary[updated_list]

# %%
dssalary
# Out:
#                       job_title  work_year employment_type company_location  \
# 0             Applied Scientist       2023              FT               US
# 1             Applied Scientist       2023              FT               US
# 2          Data Quality Analyst       2023              FT               NG
# 3       Compliance Data Analyst       2023              FT               NG
# 4             Applied Scientist       2023              FT               US
# ...                         ...        ...             ...              ...
# 3756   Principal Data Scientist       2020              FT               DE
# 3757             Data Scientist       2020              FT               AT
# 3758       Data Science Manager       2020              FT               US
# 3759  Machine Learning Engineer       2020              FT               HR
# 3760             Data Scientist       2020              FT               US
#
#      experience_level  salary_in_usd
# ...

# %% [markdown]
# - Grouping

# %%
dssalary.groupby('job_title').groups
# Out:
# {'3D Computer Vision Researcher': [1831, 2455, 3456, 3546], 'AI Developer': [58, 65, 75, 105, 211, 212, 865, 866, 1789, 1797, 2316], 'AI Programmer': [57, 1802], 'AI Scientist': [372, 893, 1819, 1859, 1862, 1935, 2219, 2225, 2228, 2402, 3479, 3508, 3509, 3521, 3654, 3703], 'Analytics Engineer': [128, 129, 307, 308, 519, 520, 586, 587, 594, 595, 596, 597, 600, 601, 620, 621, 630, 631, 686, 687, 704, 705, 706, 707, 803, 804, 906, 907, 992, 993, 1016, 1017, 1048, 1049, 1146, 1147, 1270, 1271, 1280, 1281, 1536, 1537, 1538, 1539, 1669, 1670, 1884, 1924, 1925, 1936, 1937, 1949, 1950, 1999, 2000, 2068, 2069, 2117, 2118, 2143, 2144, 2179, 2209, 2210, 2501, 2502, 2586, 2587, 2651, 2652, 2655, 2656, 2657, 2658, 2777, 2778, 2880, 2881, 2940, 2941, 2973, 2974, 3034, 3035, 3045, 3046, 3073, 3074, 3089, 3090, 3104, 3105, 3119, 3120, 3129, 3130, 3131, 3132, 3166, 3167, ...], 'Applied Data Scientist': [196, 452, 663, 1801, 1881, 2299, 3450, 3451, 3469, 3548], 'Applied Machine Learning Engineer': [18
# ...

# %%
dssalary.groupby('job_title').get_group('Data Scientist')
# Out:
#            job_title  work_year employment_type company_location  \
# 19    Data Scientist       2023              FT               CA
# 20    Data Scientist       2023              FT               US
# 21    Data Scientist       2023              FT               US
# 42    Data Scientist       2023              FT               US
# 43    Data Scientist       2023              FT               US
# ...              ...        ...             ...              ...
# 3741  Data Scientist       2020              FT               US
# 3744  Data Scientist       2020              FT               US
# 3754  Data Scientist       2020              FT               US
# 3757  Data Scientist       2020              FT               AT
# 3760  Data Scientist       2020              FT               US
#
#      experience_level  salary_in_usd
# 19                 EN          51753
# 20                 EN         130001
# 21                 EN          71907
# ...

# %%
dssalary.groupby('work_year')['salary_in_usd'].sum().plot(kind='pie',
                                                          subplots=True,
                                                          autopct='1%.1f%%',
                                                          figsize=(5,10),
                                                          layout=(2,1))
# Out:
# array([[<Axes: ylabel='salary_in_usd'>],
#        [<Axes: >]], dtype=object)

# %% [markdown]
# - pivot_table

# %%
dsspivot=dssalary.pivot_table(columns='experience_level', index='job_title', values='salary_in_usd')

# %%
dsspivot.replace(np.nan,0,inplace=True)

# %%
dsspivot.astype(int)
# Out:
# experience_level                   EN      EX      MI      SE
# job_title
# 3D Computer Vision Researcher   35000       0    5409   10000
# AI Developer                   130884       0  137510  147666
# AI Programmer                   55000       0       0       0
# AI Scientist                    52781  200000  117726  201278
# Analytics Engineer             130000  175125  102480  158404
# ...                               ...     ...     ...     ...
# Research Engineer              130000       0  178000  174773
# Research Scientist             118280   84053  141575  179892
# Software Data Engineer              0       0   75020   50000
# Staff Data Analyst                  0   15000       0       0
# Staff Data Scientist                0       0       0  105000
#
# [93 rows x 4 columns]

# %%
dssalary.to_csv('cleaner_dssalary.csv', index=False)
